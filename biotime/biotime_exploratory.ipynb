# %%
import pandas as pd

# %%
data = pd.read_csv("data/BioTIMEQuery02_04_2018.csv")
# Out:
# /home/star2/ecf3/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#    Unnamed: 0  STUDY_ID  DAY  MONTH  YEAR  \
# 0           1        10  NaN    NaN  1992
# 1           2        10  NaN    NaN  1984
# 2           3        10  NaN    NaN  1992
# 3           4        10  NaN    NaN  1992
# 4           5        10  NaN    NaN  1992
#
#                                   SAMPLE_DESC PLOT  ID_SPECIES  LATITUDE  \
# 0    47.400000_-95.120000_1_Treefall_0_Medium    1          23      47.4
# 1  47.400000_-95.120000_9_Treefall_Base_Small    9          23      47.4
# 2     47.400000_-95.120000_1_Treefall_0_Small    1        1959      47.4
# 3    47.400000_-95.120000_1_Treefall_0_Medium    1          22      47.4
# 4    47.400000_-95.120000_1_Treefall_0_Medium    1        1959      47.4
#
#    LONGITUDE  sum.allrawdata.ABUNDANCE  sum.allrawdata.BIOMASS   GENUS  \
# 0     -95.12                       1.0                     0.0    Acer
# 1     -95.12                       2.0                     0.0    Acer
# 2     -95.12                       2.0                     0.0  Prunus
# 3     -95.12                       2.0                     0.0    Acer
# 4     -95.12                       1.0                     0.0  Prunus
#
#       SPECIES      GENUS_SPECIES
# 0   saccharum     Acer saccharum
# 1   saccharum     Acer saccharum
# 2  virginiana  Prunus virginiana
# 3      rubrum        Acer rubrum
# 4  virginiana  Prunus virginiana

# %%
data.loc[ data['MONTH'] > 12 ]['MONTH'].count()
# Out:
# 12520

# %%
data.loc[ (data['STUDY_ID'] == 341) & (data['PLOT'] == 'E_28') ].sort_values(['YEAR', "MONTH"])
# Out:
#          Unnamed: 0  STUDY_ID   DAY  MONTH  YEAR SAMPLE_DESC  PLOT  \
# 6865902     6897662       341  15.0    1.0  2015   2015_E_28  E_28
# 6866700     6898460       341  16.0    1.0  2015   2015_E_28  E_28
# 6866701     6898461       341  16.0    1.0  2015   2015_E_28  E_28
# 6866702     6898462       341  16.0    1.0  2015   2015_E_28  E_28
# 6865944     6897704       341  15.0    2.0  2015   2015_E_28  E_28
# 6866785     6898545       341  16.0    2.0  2015   2015_E_28  E_28
# 6866786     6898546       341  16.0    2.0  2015   2015_E_28  E_28
# 6866787     6898547       341  16.0    2.0  2015   2015_E_28  E_28
# 6866880     6898640       341  17.0    2.0  2015   2015_E_28  E_28
# 6866440     6898200       341  30.0   11.0  2015   2015_E_28  E_28
# 6865550     6897310       341   1.0   12.0  2015   2015_E_28  E_28
# 6866083     6897843       341   2.0   12.0  2015   2015_E_28  E_28
# 6865724     6897484       341  13.0    1.0  2016   2016_E_28  E_28
# 6865916     6897676       341  15.0    1.0  2016   2016_E_28  E_28
# 6865917     6897677       341  15.0    1.0  2016   2016_E_28  E_28
# 6865441     6897201       341  10.0    2.0  2016   2016_E_28  E_28
#
#          ID_SPECIES   LATITUDE  LONGITUDE  sum.allrawdata.ABUNDANCE  \
# 6865902       44225 -23.989117 -46.745583                       3.0
# 6866700       44028 -23.988267 -46.749067                       2.0
# 6866701       44356 -23.989117 -46.745583                       5.0
# 6866702       45157 -23.989117 -46.745583                       2.0
# 6865944       44926 -23.989117 -46.745583                       5.0
# 6866785       44029 -23.989117 -46.745583                       3.0
# 6866786       44356 -23.989117 -46.745583                       3.0
# 6866787       45157 -23.989117 -46.745583                       2.0
# 6866880       45157 -23.989117 -46.745583                       2.0
# 6866440       45157 -23.989117 -46.745583                       7.0
# 6865550       45157 -23.989117 -46.745583                       2.0
# 6866083       45157 -23.989117 -46.745583                       7.0
# 6865724       45157 -23.989117 -46.745583                       4.0
# 6865916       45157 -23.988267 -46.749067                       3.0
# 6865917       45157 -23.989117 -46.745583                       4.0
# 6865441       45157 -23.989117 -46.745583                       3.0
#
#          sum.allrawdata.BIOMASS             GENUS     SPECIES  \
# 6865902                     0.0  Dendrophryniscus          sp
# 6866700                     0.0     Bokermanohyla  circumdata
# 6866701                     0.0         Fritziana    fissilis
# 6866702                     0.0         Vitrerana  uranoscopa
# 6865944                     0.0          Rhinella      ornata
# 6866785                     0.0     Bokermanohyla       hylax
# 6866786                     0.0         Fritziana    fissilis
# 6866787                     0.0         Vitrerana  uranoscopa
# 6866880                     0.0         Vitrerana  uranoscopa
# 6866440                     0.0         Vitrerana  uranoscopa
# 6865550                     0.0         Vitrerana  uranoscopa
# 6866083                     0.0         Vitrerana  uranoscopa
# 6865724                     0.0         Vitrerana  uranoscopa
# 6865916                     0.0         Vitrerana  uranoscopa
# 6865917                     0.0         Vitrerana  uranoscopa
# 6865441                     0.0         Vitrerana  uranoscopa
#
#                     GENUS_SPECIES
# 6865902       Dendrophryniscus sp
# 6866700  Bokermanohyla circumdata
# 6866701        Fritziana fissilis
# 6866702      Vitrerana uranoscopa
# 6865944           Rhinella ornata
# 6866785       Bokermanohyla hylax
# 6866786        Fritziana fissilis
# 6866787      Vitrerana uranoscopa
# 6866880      Vitrerana uranoscopa
# 6866440      Vitrerana uranoscopa
# 6865550      Vitrerana uranoscopa
# 6866083      Vitrerana uranoscopa
# 6865724      Vitrerana uranoscopa
# 6865916      Vitrerana uranoscopa
# 6865917      Vitrerana uranoscopa
# 6865441      Vitrerana uranoscopa

# %%
data.loc[ (data['sum.allrawdata.BIOMASS'] > 0.0) & (True) ]
# Out:
#          Unnamed: 0  STUDY_ID   DAY  MONTH  YEAR  \
# 28658         28659        45  17.0    7.0  2007
# 28659         28660        45  17.0    7.0  2007
# 28660         28661        45  17.0    7.0  2007
# 28661         28662        45  17.0    7.0  2007
# 28662         28663        45   1.0    8.0  2009
# ...             ...       ...   ...    ...   ...
# 8496863     8528623       512   NaN    NaN  1994
# 8496864     8528624       512   NaN    NaN  1994
# 8496865     8528625       512   NaN    NaN  1994
# 8496866     8528626       512   NaN    NaN  1994
# 8496867     8528627       512   NaN    NaN  1994
#
#                                                SAMPLE_DESC PLOT  ID_SPECIES  \
# 28658    -17.500000_-149.000000_LTER_2_Fringing_Reef_Fi...  NaN        6919
# 28659    -17.500000_-149.000000_LTER_2_Fringing_Reef_Fi...  NaN        6238
# 28660    -17.500000_-149.000000_LTER_2_Fringing_Reef_Fi...  NaN        6014
# 28661    -17.500000_-149.000000_LTER_2_Fringing_Reef_Fi...  NaN        6658
# 28662    -17.500000_-149.000000_LTER_3_Backreef_Fish_Tr...  NaN        8016
# ...                                                    ...  ...         ...
# 8496863           Torgauer_Elbtal_bei_Kunzwerda_T44_1994    T44       49337
# 8496864           Torgauer_Elbtal_bei_Kunzwerda_T44_1994    T44       50070
# 8496865           Torgauer_Elbtal_bei_Kunzwerda_T44_1994    T44       51037
# 8496866           Torgauer_Elbtal_bei_Kunzwerda_T44_1994    T44       51147
# 8496867           Torgauer_Elbtal_bei_Kunzwerda_T44_1994    T44         680
#
#           LATITUDE   LONGITUDE  sum.allrawdata.ABUNDANCE  \
# 28658   -17.500000 -149.000000                      23.0
# 28659   -17.500000 -149.000000                      19.0
# 28660   -17.500000 -149.000000                       2.0
# 28661   -17.500000 -149.000000                       1.0
# 28662   -17.500000 -149.000000                       4.0
# ...            ...         ...                       ...
# 8496863  51.527676   13.051715                       0.0
# 8496864  51.527676   13.051715                       0.0
# 8496865  51.527676   13.051715                       0.0
# 8496866  51.527676   13.051715                       0.0
# 8496867  51.527676   13.051715                       0.0
#
#          sum.allrawdata.BIOMASS           GENUS        SPECIES  \
# 28658               1417.000000        Lutjanus        kasmira
# 28659                257.540008    Gnathodentex  aureolineatus
# 28660                 39.700001     Epinephelus          merra
# 28661                  7.150000       Labroides     dimidiatus
# 28662                  1.410000  Pseudojuloides         atavai
# ...                         ...             ...            ...
# 8496863                1.000000          Urtica         dioica
# 8496864               37.500000       Agropyron         repens
# 8496865                4.000000      Potentilla        reptans
# 8496866                1.000000       Symphytum     officinale
# 8496867                1.000000        Dactylis      glomerata
#
#                       GENUS_SPECIES
# 28658              Lutjanus kasmira
# 28659    Gnathodentex aureolineatus
# 28660             Epinephelus merra
# 28661          Labroides dimidiatus
# 28662         Pseudojuloides atavai
# ...                             ...
# 8496863               Urtica dioica
# 8496864            Agropyron repens
# 8496865          Potentilla reptans
# 8496866        Symphytum officinale
# 8496867          Dactylis glomerata
#
# [2829942 rows x 15 columns]

# %%
d2 = data.rename(columns={'sum.allrawdata.ABUNDANCE': 'ABUNDANCE', 'sum.allrawdata.BIOMASS': 'BIOMASS',
                         'doesnt_exist': 'also_doesnt_exist'})
print(d2.columns.tolist())
# Out:
# ['Unnamed: 0', 'STUDY_ID', 'DAY', 'MONTH', 'YEAR', 'SAMPLE_DESC', 'PLOT', 'ID_SPECIES', 'LATITUDE', 'LONGITUDE', 'ABUNDANCE', 'BIOMASS', 'GENUS', 'SPECIES', 'GENUS_SPECIES']

# %%
from timeit import default_timer as timer
import numpy as np

# Data with only Abundance
def test(row):
#     print(row['ABUNDANCE'], row['BIOMASS'])
    return True

# def only_ab(row):
#     try:
#         if abundance > 0:
#             if biomass == 0.0 or biomass == numpy.nan:
#                 return True
#         return False
#     except TypeError:
#         print(abundance, biomass)
#         print(type(abundance), type(biomass))

t1 = timer()
d2.loc[d2['ABUNDANCE'] == 0.0, 'ab=0'] = True
t2 = timer()
d2.loc[d2['ABUNDANCE'].isna(), 'ab=na'] = True
t3 = timer()
d2.loc[d2['BIOMASS'] == 0.0, 'bio=0'] = True
t4 = timer()
d2.loc[d2['BIOMASS'].isna(), 'bio=na'] = True
t5 = timer()

# %%
print(t2-t1, t3-t2, t4-t3, t5-t4)
# Out:
# 2.176730712002609 7.005567087006057 7.110407942003803 8.83728968098876

# %%
new_cols = ['ab=0','ab=na','bio=0','bio=na']
d2[new_cols] = d2[new_cols].fillna(False)

# %%
d2.head()
# Out:
#    Unnamed: 0  STUDY_ID  DAY  MONTH  YEAR  \
# 0           1        10  NaN    NaN  1992
# 1           2        10  NaN    NaN  1984
# 2           3        10  NaN    NaN  1992
# 3           4        10  NaN    NaN  1992
# 4           5        10  NaN    NaN  1992
#
#                                   SAMPLE_DESC PLOT  ID_SPECIES  LATITUDE  \
# 0    47.400000_-95.120000_1_Treefall_0_Medium    1          23      47.4
# 1  47.400000_-95.120000_9_Treefall_Base_Small    9          23      47.4
# 2     47.400000_-95.120000_1_Treefall_0_Small    1        1959      47.4
# 3    47.400000_-95.120000_1_Treefall_0_Medium    1          22      47.4
# 4    47.400000_-95.120000_1_Treefall_0_Medium    1        1959      47.4
#
#    LONGITUDE  ABUNDANCE  BIOMASS   GENUS     SPECIES      GENUS_SPECIES  \
# 0     -95.12        1.0      0.0    Acer   saccharum     Acer saccharum
# 1     -95.12        2.0      0.0    Acer   saccharum     Acer saccharum
# 2     -95.12        2.0      0.0  Prunus  virginiana  Prunus virginiana
# 3     -95.12        2.0      0.0    Acer      rubrum        Acer rubrum
# 4     -95.12        1.0      0.0  Prunus  virginiana  Prunus virginiana
#
#     ab=0  ab=na  bio=0  bio=na
# 0  False  False   True   False
# 1  False  False   True   False
# 2  False  False   True   False
# 3  False  False   True   False
# 4  False  False   True   False

# %%
# Biomass and Abundance are 0
print("A and B are 0:", len(d2.loc[ (d2['ab=0']) & (d2['bio=0']) ]))
# Biomass and Abundance are NaN
print("A and B are NaN:", len(d2.loc[ (d2['ab=na']) & (d2['bio=na']) ]))
# Abundance is non-zero, Biomass is non-zero
any_length = len(d2.loc[ d2[new_cols].any(axis=1) ])
total_length = len(d2)
print("A and B are non-empty:", (total_length-any_length)/total_length*100, "%")
# Biomass and Abundance are empty or 0
print("A and B are both 0 or NaN:", len(d2.loc[ (d2["ab=0"] | d2['ab=na']) & (d2['bio=0'] | d2['bio=na']) ]))
# Out:
# A and B are 0: 0
# A and B are NaN: 0
# A and B are non-empty: 18.260930301776664 %
# A and B are both 0 or NaN: 0

# %% [markdown]
# ###### Conclusion:
# Biomass and Abundance are never both empty, but are only both filled 18% of the time.

# %%
len(data['GENUS_SPECIES'].unique())
# Out:
# 44575

# %%
len(data['GENUS'].unique())
# Out:
# 15475

# %%
data.groupby(["GENUS", "SPECIES"]).count().reset_index()
# Out:
#                GENUS         SPECIES  Unnamed: 0  STUDY_ID   DAY  MONTH  YEAR  \
# 0          Abagrotis        apposita          23        23    23     23    23
# 1          Abagrotis          baueri           1         1     1      1     1
# 2          Abagrotis        erratica          11        11    11     11    11
# 3          Abagrotis         forbesi           5         5     5      5     5
# 4          Abagrotis          glenni           2         2     2      2     2
# 5          Abagrotis        nefascia          19        19    19     19    19
# 6          Abagrotis         placida          13        13    13     13    13
# 7          Abagrotis       pulchrata          12        12    12     12    12
# 8          Abagrotis           reedi           4         4     4      4     4
# 9          Abagrotis        scopeops          19        19    19     19    19
# 10         Abagrotis         trigona          18        18    18     18    18
# 11         Abagrotis         variata           6         6     6      6     6
# 12         Abalistes       stellatus        1642      1642  1642   1642  1642
# 13           Abarema     barbouriana           4         4     4      4     4
# 14           Abarema      macradenia           8         8     8      8     8
# 15       Abarenicola        pacifica          25        25    25     25    25
# 16            Abdera        flexuosa          25        25    25     25    25
# 17         Aberranta      enigmatica           7         7     7      7     7
# 18         Aberranta           sp122           2         2     2      2     2
# 19       Aberrodomus        candidus           4         4     4      4     4
# 20            Aberts          Towhee        1374      1374  1374   1374  1374
# 21         Abidexter              sp           1         1     1      1     1
# 22             Abies            alba          38        38     5      5    38
# 23             Abies        amabilis        3906      3906  3906   3906  3906
# 24             Abies        balsamea         767       767   340    340   767
# 25             Abies        concolor         764       764   764    764   764
# 26             Abies         grandis         460       460   460    460   460
# 27             Abies      lasiocarpa         359       359   359    359   359
# 28             Abies       magnifica         287       287   287    287   287
# 29             Abies         procera        1625      1625  1625   1625  1625
# ...              ...             ...         ...       ...   ...    ...   ...
# 39493       Zoothera          naevia         195       195     0      0   195
# 39494       Zoothera        sibirica          59        59    59     59    59
# 39495       Zophodia  grossulariella          15        15    15     15    15
# 39496      Zoroaster  alternicanthus          75        75    75     75    75
# 39497      Zoroaster          planus           1         1     1      1     1
# 39498      Zoroaster      singletoni           4         4     4      4     4
# 39499      Zoroaster      spinulosus          24        24    24     24    24
# 39500      Zoroaster    variacanthus           1         1     1      1     1
# 39501        Zostera          marina         327       327   327    327   327
# 39502        Zostera          noltei          34        34    34     34    34
# 39503    Zosteropoda        hirtipes          63        63    63     63    63
# 39504      Zosterops       japonicus        4523      4523  4523   4523  4523
# 39505        Zotheca      tranquilla          69        69    69     69    69
# 39506             Zu       cristatus           3         3     3      3     3
# 39507             Zu       elongatus          19        19    19     19    19
# 39508       Zuelania        guidonia           8         8     8      8     8
# 39509        Zungaro         zungaro           2         2     2      2     2
# 39510     Zygeupolia          rubens          17        17    17     17    17
# 39511   Zygonemertes       virescens          34        34    32     32    34
# 39512         Zygopa       michaelis           3         3     2      2     3
# 39513      Zygopalme     crystallina           1         1     1      1     1
# 39514    Zygosphaera        marsilii           5         5     5      5     5
# 39515          Zyras        collaris           1         1     1      1     1
# 39516          Zyras              sp           2         2     2      2     2
# 39517           dead            wood          18        18    18     18    18
# 39518         imonia             sp1         197       197     0      0   197
# 39519         imonia             sp2          23        23     0      0    23
# 39520   input8_GENUS  input8_SPECIES           3         3     3      3     3
# 39521  parascorpaena      mossambica           2         2     2      2     2
# 39522       solidago      drummondii           2         2     2      2     2
#
#        SAMPLE_DESC  PLOT  ID_SPECIES  LATITUDE  LONGITUDE  \
# 0               23    23          23        23         23
# 1                1     1           1         1          1
# 2               11    11          11        11         11
# 3                5     5           5         5          5
# 4                2     2           2         2          2
# 5               19    19          19        19         19
# 6               13    13          13        13         13
# 7               12    12          12        12         12
# 8                4     4           4         4          4
# 9               19    19          19        19         19
# 10              18    18          18        18         18
# 11               6     6           6         6          6
# 12            1642     0        1642      1642       1642
# 13               4     0           4         4          4
# 14               8     0           8         8          8
# 15              25    13          25        25         25
# 16              25    25          25        25         25
# 17               7     0           7         7          7
# 18               2     0           2         2          2
# 19               4     0           4         4          4
# 20            1374     0        1374      1374       1374
# 21               1     1           1         1          1
# 22              38    38          38        38         38
# 23            3906     0        3906      3906       3906
# 24             767   287         767       767        767
# 25             764     0         764       764        764
# 26             460     0         460       460        460
# 27             359     0         359       359        359
# 28             287     0         287       287        287
# 29            1625     0        1625      1625       1625
# ...            ...   ...         ...       ...        ...
# 39493          195   195         195       195        195
# 39494           59    59          59        59         59
# 39495           15     0          15        15         15
# 39496           75     0          75        75         75
# 39497            1     0           1         1          1
# 39498            4     0           4         4          4
# 39499           24     0          24        24         24
# 39500            1     0           1         1          1
# 39501          327     9         327       327        327
# 39502           34     0          34        34         34
# 39503           63    63          63        63         63
# 39504         4523  4523        4523      4523       4523
# 39505           69    69          69        69         69
# 39506            3     0           3         3          3
# 39507           19     0          19        19         19
# 39508            8     0           8         8          8
# 39509            2     0           2         2          2
# 39510           17     0          17        17         17
# 39511           34     0          34        34         34
# 39512            3     0           3         3          3
# 39513            1     0           1         1          1
# 39514            5     0           5         5          5
# 39515            1     0           1         1          1
# 39516            2     2           2         2          2
# 39517           18    18          18        18         18
# 39518          197   197         197       197        197
# 39519           23    23          23        23         23
# 39520            3     3           3         3          3
# 39521            2     0           2         2          2
# 39522            2     0           2         2          2
#
#        sum.allrawdata.ABUNDANCE  sum.allrawdata.BIOMASS  GENUS_SPECIES
# 0                            23                      23             23
# 1                             1                       1              1
# 2                            11                      11             11
# 3                             5                       5              5
# 4                             2                       2              2
# 5                            19                      19             19
# 6                            13                      13             13
# 7                            12                      12             12
# 8                             4                       4              4
# 9                            19                      19             19
# 10                           18                      18             18
# 11                            6                       6              6
# 12                         1642                    1642           1642
# 13                            4                       4              4
# 14                            8                       8              8
# 15                           25                      25             25
# 16                           25                      25             25
# 17                            7                       7              7
# 18                            2                       2              2
# 19                            4                       4              4
# 20                         1374                    1374           1374
# 21                            1                       1              1
# 22                           38                      38             38
# 23                         3906                    3906           3906
# 24                          767                     767            767
# 25                          764                     764            764
# 26                          460                     460            460
# 27                          359                     359            359
# 28                          287                     287            287
# 29                         1625                    1625           1625
# ...                         ...                     ...            ...
# 39493                       195                     195            195
# 39494                        59                      59             59
# 39495                        15                      15             15
# 39496                        75                      75             75
# 39497                         1                       1              1
# 39498                         4                       4              4
# 39499                        24                      24             24
# 39500                         1                       1              1
# 39501                       327                     327            327
# 39502                        34                      34             34
# 39503                        63                      63             63
# 39504                      4523                    4523           4523
# 39505                        69                      69             69
# 39506                         3                       3              3
# 39507                        19                      19             19
# 39508                         8                       8              8
# 39509                         2                       2              2
# 39510                        17                      17             17
# 39511                        34                      34             34
# 39512                         3                       3              3
# 39513                         1                       1              1
# 39514                         5                       5              5
# 39515                         1                       1              1
# 39516                         2                       2              2
# 39517                        18                      18             18
# 39518                       197                     197            197
# 39519                        23                      23             23
# 39520                         3                       3              3
# 39521                         2                       2              2
# 39522                         2                       2              2
#
# [39523 rows x 15 columns]

# %%
genus = data.groupby("GENUS")['SPECIES'].count().reset_index()

# %%
genus.loc[ genus['SPECIES'] == 0 ].head(20)
# Out:
#        GENUS  SPECIES
# 0       ABTO        0
# 1    ACERALB        0
# 2       ACWO        0
# 3       AGEL        0
# 4       AGWT        0
# 5   ALNUCRIS        0
# 6   ALNUTENU        0
# 7       AMAV        0
# 8       AMCO        0
# 9       AMCR        0
# 10   AMELARB        0
# 11   AMELCAN        0
# 12      AMGO        0
# 13      AMKE        0
# 14      AMPI        0
# 15      AMRO        0
# 16      AMWI        0
# 17      ANHU        0
# 18      ATFL        0
# 19      AUWA        0

# %%
data[ (data['GENUS'] == "Alnus") ]['SPECIES'].unique()
# Out:
# array(['rubra', 'incana', 'sinuata', 'glutinosa', 'sp', 'viridis'],
#       dtype=object)

# %% [markdown]
# ### Checking the date data

# %%
mdata = data.loc[ (data['MONTH'] > 0) ]
mdata2 = data.loc[ (data['MONTH'] > 0) & (data['DAY'] > 0)]
print("Data:", len(data))
print("MData:", len(mdata))
print("MData2:", len(mdata2))
# Out:
# Data: 8547248
# MData: 7138870
# MData2: 7115466

# %%
# All rows that have an invalid month value
print(len(data.loc[data['MONTH'] > 12]))
print(len(mdata.loc[mdata['MONTH'] > 12]))
print(len(mdata2.loc[mdata2['MONTH'] > 12]))
# Out:
# 12520
# 12520
# 12520

# %%
# All rows that have an invalid month value that could have had their month-day values switched.
len(mdata2.loc[(mdata2['MONTH'] > 12) & (mdata2['DAY'] <= 12)])
# Out:
# 12520

# %%
# All rows with technically valid month values that could also be wrong
at_risk_rows = len(mdata2.loc[(mdata2['MONTH'] <= 12) & (mdata2['DAY'] <= 12)])
print(at_risk_rows)
# Out:
# 3163167

# %%
# Remaining rows that are presumably safe
print((len(mdata2) - at_risk_rows)/len(mdata2)* 100, "%")
# Out:
# 55.545188466925424 %

# %%
print((len(mdata) - at_risk_rows)/len(mdata)* 100, "%")
# Out:
# 55.690928676387166 %

# %%
# Finding the study IDs of the switched rows
mdata2.loc[(mdata2['MONTH'] > 12) & (mdata2['DAY'] <= 12)]['STUDY_ID'].value_counts()
# Out:
# 321    9218
# 54     3302
# Name: STUDY_ID, dtype: int64

# %%
len(mdata2.loc[ mdata2['STUDY_ID'].isin([321, 54])])
# Out:
# 34172

# %%
len(data.loc[ data['STUDY_ID'].isin([321, 54])])
# Out:
# 34172

# %% [markdown]
# #### Conclusion:
# All invalid month data could have been the result of Americanized date systems, getting the month and the day mixed up.
# However, given that this has happened, that means that there are at least `3 Million` rows of data in which the month and day could still have been mixed up, without being able to tell.

# %%
data.tail()
# Out:
#          Unnamed: 0  STUDY_ID  DAY  MONTH  YEAR                   SAMPLE_DESC  \
# 8547243    44065100       249  9.0    9.0  2007  9_9_2007_55.702512_12.558956
# 8547244    44066100       249  9.0    9.0  2007  9_9_2007_55.702512_12.558956
# 8547245    44067100       249  9.0    9.0  2007  9_9_2007_55.702512_12.558956
# 8547246    44068100       249  9.0    9.0  2007  9_9_2007_55.702512_12.558956
# 8547247    44069100       249  9.0    9.0  2007  9_9_2007_55.702512_12.558956
#
#         PLOT  ID_SPECIES   LATITUDE  LONGITUDE  sum.allrawdata.ABUNDANCE  \
# 8547243  NaN       39472  55.702512  12.558956                      25.0
# 8547244  NaN       39478  55.702512  12.558956                       4.0
# 8547245  NaN       39481  55.702512  12.558956                       2.0
# 8547246  NaN       39490  55.702512  12.558956                       1.0
# 8547247  NaN       39493  55.702512  12.558956                       1.0
#
#          sum.allrawdata.BIOMASS       GENUS        SPECIES  \
# 8547243                     0.0      Xestia       c-nigrum
# 8547244                     0.0  Yponomeuta     cagnagella
# 8547245                     0.0  Yponomeuta     malinellus
# 8547246                     0.0   Ypsolopha  parenthesella
# 8547247                     0.0   Ypsolopha       sylvella
#
#                    GENUS_SPECIES
# 8547243          Xestia c-nigrum
# 8547244    Yponomeuta cagnagella
# 8547245    Yponomeuta malinellus
# 8547246  Ypsolopha parenthesella
# 8547247       Ypsolopha sylvella

# %%
metadata = pd.read_csv("data/metadata.csv")

# %%
metadata.head()
# Out:
#    STUDY_ID        REALM    CLIMATE GENERAL_TREAT TREATMENT TREAT_COMMENTS  \
# 0        10  Terrestrial  Temperate           NaN       NaN            NaN
# 1        18  Terrestrial  Temperate           NaN       NaN            NaN
# 2        33       Marine  Temperate           NaN       NaN            NaN
# 3        39  Terrestrial  Temperate           NaN       NaN            NaN
# 4        41  Terrestrial  Temperate           NaN       NaN            NaN
#
#   TREAT_DATE           HABITAT  PROTECTED_AREA  \
# 0        NaN          Woodland           False
# 1        NaN  Sagebrush steppe           False
# 2        NaN      Seaweed beds           False
# 3        NaN  Deciduous forest           False
# 4        NaN          Woodland           False
#
#                                BIOME_MAP     ...      Unnamed: 56 Unnamed: 57  \
# 0  Temperate broadleaf and mixed forests     ...              NaN         NaN
# 1           Deserts and xeric shrublands     ...              NaN         NaN
# 2    Temperate shelf and seas ecoregions     ...              NaN         NaN
# 3  Temperate broadleaf and mixed forests     ...              NaN         NaN
# 4  Temperate broadleaf and mixed forests     ...              NaN         NaN
#
#   Unnamed: 58 Unnamed: 59 Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63  \
# 0         NaN         NaN         NaN          NaN          NaN          NaN
# 1         NaN         NaN         NaN          NaN          NaN          NaN
# 2         NaN         NaN         NaN          NaN          NaN          NaN
# 3         NaN         NaN         NaN          NaN          NaN          NaN
# 4         NaN         NaN         NaN          NaN          NaN          NaN
#
#    Unnamed: 64  Unnamed: 65
# 0          NaN          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
#
# [5 rows x 66 columns]

# %%
metadata['CLIMATE'].unique()
# Out:
# array(['Temperate', 'Tropical', 'Polar', 'Polar/Temperate',
#        'Temperate/Tropical', 'Global'], dtype=object)

# %%
len(metadata.columns.tolist())
# Out:
# 66

# %%
metadata.columns.tolist()
# Out:
# ['STUDY_ID',
#  'REALM',
#  'CLIMATE',
#  'GENERAL_TREAT',
#  'TREATMENT',
#  'TREAT_COMMENTS',
#  'TREAT_DATE',
#  'HABITAT',
#  'PROTECTED_AREA',
#  'BIOME_MAP',
#  'TAXA',
#  'ORGANISMS',
#  'TITLE',
#  'AB_BIO',
#  'HAS_PLOT',
#  'DATA_POINTS',
#  'START_YEAR',
#  'END_YEAR',
#  'CENT_LAT',
#  'CENT_LONG',
#  'NUMBER_OF_SPECIES',
#  'NUMBER_OF_SAMPLES',
#  'NUMBER_LAT_LONG',
#  'TOTAL',
#  'GRAIN_SIZE_TEXT',
#  'GRAIN_SQ_KM',
#  'AREA_SQ_KM',
#  'CONTACT_1',
#  'CONTACT_2',
#  'CONT_1_MAIL',
#  'CONT_2_MAIL',
#  'LICENSE',
#  'WEB_LINK',
#  'DATA_SOURCE',
#  'METHODS',
#  'SUMMARY_METHODS',
#  'LINK_ID',
#  'COMMENTS',
#  'DATE_STUDY_ADDED',
#  'ABUNDANCE_TYPE',
#  'BIOMASS_TYPE',
#  'SAMPLE_DESC_NAME',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55',
#  'Unnamed: 56',
#  'Unnamed: 57',
#  'Unnamed: 58',
#  'Unnamed: 59',
#  'Unnamed: 60',
#  'Unnamed: 61',
#  'Unnamed: 62',
#  'Unnamed: 63',
#  'Unnamed: 64',
#  'Unnamed: 65']

# %%
metadata.loc[ metadata['STUDY_ID'].isin([321, 54])]['WEB_LINK']
# Out:
# 11     http://luq.lternet.edu/data/luqmetadata107/7427
# 175    http://jornada.nmsu.edu/lter/dataset/49798/view
# Name: WEB_LINK, dtype: object
