# %% [markdown]
# # Stuff to include:
# * Load data into dataframe
# * .head(), .head(5)
# * .info()
# * .shape
# * .columns
# * .rename(dict{'orig_name':'new_name'})
# * .isnull(), .sum() - To work out the number of null values in a column
# * Select a column, or combination of columns - `df[['col1, col2']]`
# * .describe()
# * df['column'].describe()
# * .value_counts()
#
# * Filter dataframe by a condition - `df[ df['col'] == Val ]`
# * Get unique values - `df['col'].unqiue()`
# * Get unique combinations of column values
# * Create a new column from existing columns
# * Join two datasets together
# * .apply() to create a new column
# * Plot some data
#
# * Analysis suggestions to get them started
#
# * Creating a new column through the df.apply() function, especially with Lambda functions

# %% [markdown]
# Something about using axis=1 for operations like `.apply()` to make sure it runs over rows, instead of columns.
# Potentially something about using these operations over columns as well.

# %% [markdown]
# * Create a new column from existing columns
# * Join two datasets together
# * .apply() to create a new column
# * Plot some data
#
# * Analysis suggestions to get them started
#
# * Creating a new column through the df.apply() function, especially with Lambda functions

# %% [markdown]
# ## New Outline
#
# ### Suggestions
#
# #### Hotkeys
#
# #### Nb_extensions for contents menu (include picture)
#
# ### Importing
# Import numpy, pandas as np, pd
#
# ### Creating a DataFrame
# Creating an object (can probably restrict only to DataFrames?).
# * Create from Dict
# * Read in from CSV
# * Read in from Excel
#
# ### DataFrame Explanation
# Description of how a DataFrame is composed?
#
# ### DataFrame Exploration
# df.head()
# df.head(50)
# df.tail()
# df.shape
# df.index
# df.columns
#
# changing column names
# df.rename()
# df.rename(axis=1)
#
# series.value_counts()
# series.unique()
# series.unique([])
#
#
# #### Further Exploration
# df.info()
# df.describe()
#
# #### Selecting Data
# df.loc()
# df.iloc()
# df[], df[[]]
# filtering data (df[ df["colname"] == "value" ])
#
# ### Reshape Data
# df.melt()
# df.pivot()
#
# ### Combine Data
# merge
# join
# concatenate
# compare (?)
#
# Use df.apply() to create a new column
#
# ### Groupby
# Split
# apply
# combine
#
# ## Plotting
#
# ## Reading Large Files
#
# ## Further Reading
# Links here
