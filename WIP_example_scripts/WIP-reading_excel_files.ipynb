# %%
import pandas as pd

# %%
xfile = pd.ExcelFile("example_data/general-election-results-2019.xlsx")

# %%
vars(xfile.book)
# Out:
# {'_sheet_list': [<xlrd.sheet.Sheet at 0x7f33e4d49048>,
# ...
#  '_sheet_names': ['Data for your constituency',
#   'voting-summary',
#   'voting-full',
#   'Data guide'],
#  '_sheet_visibility': [0, 0, 0, 0],
#  'nsheets': 4,
#  '_sh_abs_posn': [],
#  '_sharedstrings': ['County',
#   'England',
#   'Yorkshire and The Humber',
#   'North Yorkshire',
#   'York Outer',
#   'E12000003',
#   'E14001062',
#   'Borough',
#   'York Central',
#   'E14001061',
#   'Wales',
#   'Gwynedd',
#   'Ynys Mon',
#   'W92000004',
#   'W07000041',
#   'South West',
#   'Somerset',
#   'Yeovil',
#   'E12000009',
#   'E14001060',
#   'North West',
#   'Greater Manchester',
#   'Wythenshawe and Sale East',
#   'E12000002',
#   'E14001059',
#   'West Midlands',
#   'Hereford and Worcester',
#   'Wyre Forest',
#   'E12000005',
#   'E14001058',
#   'Lancashire',
#   'Wyre and Preston North',
#   'E14001057',
#   'South East',
#   'Buckinghamshire',
#   'Wycombe',
#   'E12000008',
#   'E14001056',
#   'Clwyd',
# ...

# %%
df1 = pd.read_excel(xfile, "Data for your constituency")

# %%
df2 = pd.read_excel(xfile, "voting-summary")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 650 entries, 0 to 649
# Data columns (total 39 columns):
# ons_id               650 non-null object
# ons_region_id        650 non-null object
# constituency_name    650 non-null object
# county_name          650 non-null object
# region_name          650 non-null object
# country_name         650 non-null object
# constituency_type    650 non-null object
# declaration_time     650 non-null datetime64[ns]
# mp_firstname         650 non-null object
# mp_surname           650 non-null object
# mp_gender            650 non-null object
# result               650 non-null object
# first_party          650 non-null object
# second_party         650 non-null object
# electorate           650 non-null int64
# valid_votes          650 non-null int64
# invalid_votes        650 non-null int64
# majority             650 non-null int64
# con                  650 non-null int64
# lab                  650 non-null int64
# ...
