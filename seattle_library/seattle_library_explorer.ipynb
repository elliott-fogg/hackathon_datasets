# %%
import pandas as pd

# %%
data = pd.read_csv("../potential_datasets/seattle_library/Checkouts_by_Title.csv")

# %%
data.head()
# Out:
#   UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 0   Physical      Horizon         BOOK          2010              9
# 1   Physical      Horizon    SOUNDDISC          2010              9
# 2   Physical      Horizon    SOUNDDISC          2010              9
# 3   Physical      Horizon    SOUNDDISC          2010              9
# 4   Physical      Horizon         BOOK          2010              9
#
#    Checkouts                                              Title  \
# 0          1            Best log home plans / Robbin Obomsawin.
# 1          2   The Labrador pact [sound recording] / Matt Haig.
# 2          1          Heres to you Charlie Brown 50 great years
# 3          2  Violin concertos [sound recording] / Beethoven...
# 4          3  The boy, the bear, the baron, the bard / Grego...
#
#                             Creator  \
# 0          Obomsawin, Robbin, 1960-
# 1                 Haig, Matt, 1975-
# 2                               NaN
# ...

# %%
data.tail()
# Out:
#          UsageClass CheckoutType MaterialType  CheckoutYear  CheckoutMonth  \
# 35312541   Physical      Horizon    VIDEODISC          2010              9
# 35312542   Physical      Horizon         BOOK          2010              9
# 35312543   Physical      Horizon         BOOK          2010              9
# 35312544   Physical      Horizon    SOUNDDISC          2010              9
# 35312545   Physical      Horizon         BOOK          2010              9
#
#           Checkouts                                              Title  \
# 35312541         23  A clockwork orange [videorecording] / Warner B...
# 35312542          1       Brief an Lord Liszt : Roman / Martin Walser.
# 35312543          2  different mirror a history of multicultural Am...
# 35312544          2                                        fiery cross
# 35312545          4         Outlook 2007 for dummies / by Bill Dyszel.
#
#                         Creator  \
# 35312541                    NaN
# ...

# %%
d2 = data.loc[ data['Creator'].notna() ]

# %%
data['MaterialType'].unique()
# Out:
# array(['BOOK', 'SOUNDDISC', 'AUDIOBOOK', 'VIDEODISC', 'MUSIC', 'EBOOK',
#        'VIDEO', 'MIXED', 'ER', 'SOUNDCASS', 'VIDEOCASS', 'SOUNDREC', 'CR',
#        'SOUNDDISC, VIDEODISC', 'ATLAS', 'MUSICSNDREC', 'VISUAL',
#        'ER, SOUNDDISC', 'ER, VIDEODISC',
#        'SOUNDCASS, SOUNDDISC, VIDEOCASS, VIDEODISC', 'MAP', 'KIT',
#        'ER, PICTURE', 'MICROFORM', 'SONG', 'FLASHCARD, SOUNDDISC',
#        'COMPFILE', 'GLOBE', 'SLIDE, VIDEOCASS', 'SLIDE, SOUNDCASS',
#        'REGPRINT', 'SOUNDCASS, SOUNDDISC', 'SOUNDDISC, VIDEOCASS',
#        'ER, VIDEOREC', 'VIDEOREC', 'VIDEOCART', 'ER, PRINT',
#        'SOUNDDISC, SOUNDREC', 'SLIDE, SOUNDCASS, VIDEOCASS', 'ER, MAP',
#        'SOUNDCASS, VIDEOCASS', 'SLIDE', 'PICTURE', 'PRINT',
#        'PICTURE, VIDEODISC', 'ER, NONPROJGRAPH', 'ATLAS, ER', 'MOVIE',
#        'MAGAZINE', 'TELEVISION', 'LARGEPRINT', 'NOTATEDMUSIC',
#        'MAP, VIEW', 'SECTION', 'CHART', 'VIDEOCASS, VIDEODISC',
# ...

# %%
d3 = data['MaterialType'].str.split()

# %%
d4 = d3.astype(tuple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-711e723fccf8> in <module>
# ----> 1 d4 = d3.astype(tuple)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ...

# %%
a = set()
for i in d3:
    for j in i:
        a.add(j)

# %%
b = set()
for q in a:
    if not (',' in q):
        b.add(q)

# %%
b
# Out:
# {'ATLAS',
#  'AUDIOBOOK',
#  'BOOK',
#  'CHART',
#  'COMIC',
#  'COMPFILE',
#  'CR',
#  'EBOOK',
#  'ER',
#  'FLASHCARD',
#  'GLOBE',
#  'KIT',
#  'LARGEPRINT',
#  'MAGAZINE',
#  'MAP',
#  'MICROFORM',
#  'MIXED',
#  'MOVIE',
#  'MUSIC',
#  'MUSICSNDREC',
#  'NONPROJGRAPH',
#  'NOTATEDMUSIC',
#  'PICTURE',
#  'PRINT',
#  'REGPRINT',
#  'REMOTESEN',
#  'SECTION',
#  'SLIDE',
#  'SONG',
#  'SOUNDCASS',
#  'SOUNDDISC',
#  'SOUNDREC',
#  'TELEVISION',
#  'UNSPECIFIED',
#  'VIDEO',
#  'VIDEOCART',
#  'VIDEOCASS',
#  'VIDEODISC',
#  'VIDEOREC',
#  'VIEW',
#  'VISUAL'}
